# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/logo_ciencia_datos.png">

# %% [markdown]
# <center><h2 style="font-size:2em;color:#840700">   Análisis exploratorio con Folium  </h4></center>

# %% [markdown]
# <br><center><h1 style="font-size:2em;color:#2467C0"> Visualización geoespacial con  Folium </h1></center>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="figuras/MapaMerida.png" align="middle" style="width:550px"/></td>
# <td>
#
#
# Folium (https://python-visualization.github.io/folium/) es una de las librerías más asequibles para análisis y representación geoespacial, por la sencillez de la sintaxis.
#
#
# Una de las características que más atrae es que no necesita convertir el DataFrame en un GeoDataFrame. Solo teniendo una serie con la latitud y otra serie con la longitud del punto espacial, es suficiente para que Folium lo represente en un mapa.
#
# </td>
# </tr>
# </table>

# %% [markdown]
# # Folium

# %% [markdown]
# _**Folium**_ es una poderosa biblioteca de visualización de datos en Python que se creó principalmente para ayudar a visualizar datos *geoespaciales*. Con Folium, se puede crear un mapa de cualquier lugar del mundo siempre que se conozcan sus valores de *latitud* y *longitud*. Además, los mapas creados por _**Folium**_ son de naturaleza interactiva, por lo que se puede acercar y alejar después de renderizar el mapa, lo cual es una característica muy útil.

# %% [markdown]
# # Configuración inicial

# %% [markdown]
# Folium proporciona la clase ``folium.Map()`` que toma el parámetro de ubicación en términos de latitud y longitud, para generar un mapa a su alrededor. Entonces, tracemos un mapa de la ciudad de Merida con latitud y longitud como _21.0530 y -89.6332_ respectivamente:

# %%
import folium
mapa = folium.Map(location=[21.0530, -89.6332])
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1523309baf0ec473fe7ce19eb1e730cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1523309baf0ec473fe7ce19eb1e730cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1523309baf0ec473fe7ce19eb1e730cd = L.map(
#                 &quot;map_1523309baf0ec473fe7ce19eb1e730cd&quot;,
#                 {
#                     center: [21.053, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fc7002080efe846c703f83c6ec6ebfd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1523309baf0ec473fe7ce19eb1e730cd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Puede ver que estos mapas son interactivos. Puede acercar y alejar haciendo clic en los botones positivo y negativo en la esquina superior izquierda del mapa. También puede arrastrar el mapa y ver diferentes regiones.
#
# A continuación, pasemos al segundo problema y cambiemos el nivel de zoom. De forma predeterminada, puede acercar y alejar tanto como desee. Además, el nivel de zoom inicial se fija en 10 (el mapa se traza con un zoom de 10x).  Para hacer esto, Folium nos da tres parámetros: ``zoom_start``, ``min_zoom`` y ``max_zoom``.
#
# Entonces, tracemos nuevamente el mapa de Mérida pero esta vez de con un nivel de zoom desde el inicio:

# %%
mapa = folium.Map(location=[20.9785, -89.6332],zoom_start=13)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec7c3b25277881b2e98bb718295a5a1b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec7c3b25277881b2e98bb718295a5a1b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec7c3b25277881b2e98bb718295a5a1b = L.map(
#                 &quot;map_ec7c3b25277881b2e98bb718295a5a1b&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18f09d4641ea88be52cad91e860a2595 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ec7c3b25277881b2e98bb718295a5a1b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ahora tracemos nuevamente el mapa de Mérida  con un nivel de zoom restringido:

# %%
mapa = folium.Map(location=[20.9785, -89.6332],zoom_start=12,min_zoom=10,max_zoom=13)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27ac0fbf0825ae205a314174a611ce14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27ac0fbf0825ae205a314174a611ce14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27ac0fbf0825ae205a314174a611ce14 = L.map(
#                 &quot;map_27ac0fbf0825ae205a314174a611ce14&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5188976f617382dbba2f104146239ee1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 13, &quot;maxZoom&quot;: 13, &quot;minZoom&quot;: 10, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_27ac0fbf0825ae205a314174a611ce14);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Marcadores en el mapa

# %% [markdown]
# Los marcadores son los elementos que se utilizan para marcar una ubicación en un mapa. Por ejemplo, cuando utiliza _Google Maps_ para la navegación, su ubicación se marca con un marcador y su destino se marca con otro marcador. Los marcadores se encuentran entre los elementos más importantes y útiles de un mapa.
#
# _**Folium**_ proporciona una clase  ``folium.Marker ()``  para trazar marcadores en un mapa. Simplemente pase la latitud y la longitud de la ubicación, mencione la ventana emergente y la información sobre herramientas y agréguela al mapa.
#
# Agregar marcadores es un proceso de dos pasos. Primero, debe crear un mapa base en el que se colocarán sus marcadores, y luego agregar sus marcadores. En el siguiente ejemplo se muestra su implementación junto con algunas opciones extras de visualización:

# %%
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12)
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025],popup='FIUADY').add_to(mapa)
folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',tooltip='<strong>Click here to see Popup</strong>').add_to(mapa)
folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',tooltip='<strong>Click here to see Popup</strong>').add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac22b2abf92e910503dc30221ca97003 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac22b2abf92e910503dc30221ca97003&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac22b2abf92e910503dc30221ca97003 = L.map(
#                 &quot;map_ac22b2abf92e910503dc30221ca97003&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6199c07f2d100f0928e4f1be1949209a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ac22b2abf92e910503dc30221ca97003);
#
#
#             var marker_67dfa70f86d66a6b204b88c0b1bc4b4a = L.marker(
#                 [21.04829, -89.64025],
#                 {}
#             ).addTo(map_ac22b2abf92e910503dc30221ca97003);
#
#
#         var popup_4963faa7a651a0d2e4f358e1969b4be0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_671213c4ef1fe051f6d3d196a97ca876 = $(`&lt;div id=&quot;html_671213c4ef1fe051f6d3d196a97ca876&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_4963faa7a651a0d2e4f358e1969b4be0.setContent(html_671213c4ef1fe051f6d3d196a97ca876);
#
#
#
#         marker_67dfa70f86d66a6b204b88c0b1bc4b4a.bindPopup(popup_4963faa7a651a0d2e4f358e1969b4be0)
#         ;
#
#
#
#
#             var marker_f199eaa9f87a30ef5f79b24e096f65f7 = L.marker(
#                 [20.96972, -89.62272],
#                 {}
#             ).addTo(map_ac22b2abf92e910503dc30221ca97003);
#
#
#         var popup_851946b43ca5f282c11ffe09d29d037b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cd1118c80a04a18573656e9f526de6e9 = $(`&lt;div id=&quot;html_cd1118c80a04a18573656e9f526de6e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_851946b43ca5f282c11ffe09d29d037b.setContent(html_cd1118c80a04a18573656e9f526de6e9);
#
#
#
#         marker_f199eaa9f87a30ef5f79b24e096f65f7.bindPopup(popup_851946b43ca5f282c11ffe09d29d037b)
#         ;
#
#
#
#
#             marker_f199eaa9f87a30ef5f79b24e096f65f7.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6b169c3f4c03885b9e6dda22e540e5f8 = L.marker(
#                 [20.94167, -89.59466],
#                 {}
#             ).addTo(map_ac22b2abf92e910503dc30221ca97003);
#
#
#         var popup_9951975cbbd20dd19633b1b3e865c410 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75449e2b8dc11e7ebb3b1810c47d00e3 = $(`&lt;div id=&quot;html_75449e2b8dc11e7ebb3b1810c47d00e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_9951975cbbd20dd19633b1b3e865c410.setContent(html_75449e2b8dc11e7ebb3b1810c47d00e3);
#
#
#
#         marker_6b169c3f4c03885b9e6dda22e540e5f8.bindPopup(popup_9951975cbbd20dd19633b1b3e865c410)
#         ;
#
#
#
#
#             marker_6b169c3f4c03885b9e6dda22e540e5f8.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# En el mapa anteriorcuando pasa el cursor sobre un marcador el texto que aparece se conoce como ``tooltip`` (información sobre herramienta)  y el texto cuando hace clic en un marcador se conoce como una ``popup`` (ventana emergente). Si se observa detenidamente, se ha  personalizado la información  de los marcadores 2 y 3.

# %% [markdown]
# ## Marcadores personalizados

# %% [markdown]
# Para mejorar la visualización puede cambiar el icono del marcador, Folium proporciona la clase ``folium.Icon()`` que se puede utilizar para crear iconos personalizados para marcadores. Puede elegir iconos entre una amplia gama de opciones.
#
# ``Icon()`` toma tres argumentos: color, prefijo e icono. El color se utiliza para cambiar el color del marcador, el prefijo se utiliza para seleccionar el proveedor de iconos (prefix='fa' para https://fontawesome.com/icons?d=gallery&m=free y  prefix='glyphicon' para  https://getbootstrap.com/docs/3.3/components/) y el icono se utiliza para seleccionar el nombre del icono.

# %%
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12)
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red',icon='none') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='school-flag')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='glyphicon glyphicon-adjust')   ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0d40fa1985037ed6baa5fddfd2438f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0d40fa1985037ed6baa5fddfd2438f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0d40fa1985037ed6baa5fddfd2438f5 = L.map(
#                 &quot;map_d0d40fa1985037ed6baa5fddfd2438f5&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e7e04a174c51f5722f618d00041c97d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d0d40fa1985037ed6baa5fddfd2438f5);
#
#
#             var marker_fb28d46b6811f10e1c46391eb8685ab1 = L.marker(
#                 [21.04829, -89.64025],
#                 {}
#             ).addTo(map_d0d40fa1985037ed6baa5fddfd2438f5);
#
#
#             var icon_5550abc98184fb48260a148e751fc40d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;none&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fb28d46b6811f10e1c46391eb8685ab1.setIcon(icon_5550abc98184fb48260a148e751fc40d);
#
#
#         var popup_d4737a59e04308656d5e1f644bc7068d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_71d6d89676491a2973b3ec6a3baae751 = $(`&lt;div id=&quot;html_71d6d89676491a2973b3ec6a3baae751&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_d4737a59e04308656d5e1f644bc7068d.setContent(html_71d6d89676491a2973b3ec6a3baae751);
#
#
#
#         marker_fb28d46b6811f10e1c46391eb8685ab1.bindPopup(popup_d4737a59e04308656d5e1f644bc7068d)
#         ;
#
#
#
#
#             var marker_a0be880a7939f8f144fd4789b74c9d1d = L.marker(
#                 [20.96972, -89.62272],
#                 {}
#             ).addTo(map_d0d40fa1985037ed6baa5fddfd2438f5);
#
#
#             var icon_a5324ccf8c275087a5b7e45387aafe2e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;school-flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a0be880a7939f8f144fd4789b74c9d1d.setIcon(icon_a5324ccf8c275087a5b7e45387aafe2e);
#
#
#         var popup_44584da10ab54d5baec1f4ae633d8a49 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e3d6f43debc36fdec47709124c44f9d1 = $(`&lt;div id=&quot;html_e3d6f43debc36fdec47709124c44f9d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_44584da10ab54d5baec1f4ae633d8a49.setContent(html_e3d6f43debc36fdec47709124c44f9d1);
#
#
#
#         marker_a0be880a7939f8f144fd4789b74c9d1d.bindPopup(popup_44584da10ab54d5baec1f4ae633d8a49)
#         ;
#
#
#
#
#             marker_a0be880a7939f8f144fd4789b74c9d1d.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_61edae60494b2249b367503304b45871 = L.marker(
#                 [20.94167, -89.59466],
#                 {}
#             ).addTo(map_d0d40fa1985037ed6baa5fddfd2438f5);
#
#
#             var icon_07f282cd3af50ce05dc1270fb971d028 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-adjust&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_61edae60494b2249b367503304b45871.setIcon(icon_07f282cd3af50ce05dc1270fb971d028);
#
#
#         var popup_8a4713fc7f46b102e549319fc24a54d9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f0e68f755d921190dfe73fb6172f8282 = $(`&lt;div id=&quot;html_f0e68f755d921190dfe73fb6172f8282&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_8a4713fc7f46b102e549319fc24a54d9.setContent(html_f0e68f755d921190dfe73fb6172f8282);
#
#
#
#         marker_61edae60494b2249b367503304b45871.bindPopup(popup_8a4713fc7f46b102e549319fc24a54d9)
#         ;

# %% [markdown]
# ## Marcadores  tipo circunferencia

# %% [markdown]
# Se realiza mediante la función ``folium.Circle``. Cada circunferencia tiene un tamaño relacionado con un valor específico, a través del parametro ``radius`` (metros).

# %%
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12 )
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red',icon='none') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='crosshairs')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='camera')   ).add_to(mapa)


folium.Circle(
    radius=500,
    location=[20.956972, -89.62272],
    popup='Sur',
    color='crimson',
    fill=False,
).add_to(mapa)

folium.Circle(
    location=[20.996972, -89.62272],
    radius=1500,
    popup='Norte',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(mapa)


mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2897a4e796046a5f3c4a43e05caaa9bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2897a4e796046a5f3c4a43e05caaa9bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2897a4e796046a5f3c4a43e05caaa9bb = L.map(
#                 &quot;map_2897a4e796046a5f3c4a43e05caaa9bb&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b98658245ae8c9a954f1e61b94b9548d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2897a4e796046a5f3c4a43e05caaa9bb);
#
#
#             var marker_a29957b3cb12cef288de6691298baf34 = L.marker(
#                 [21.04829, -89.64025],
#                 {}
#             ).addTo(map_2897a4e796046a5f3c4a43e05caaa9bb);
#
#
#             var icon_5e95bd2e248e08a2493771703ab24070 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;none&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a29957b3cb12cef288de6691298baf34.setIcon(icon_5e95bd2e248e08a2493771703ab24070);
#
#
#         var popup_02ff735119f8381ad21c29d66530aa59 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_83ccd4bc1e5f9b585bfd753ca45e2748 = $(`&lt;div id=&quot;html_83ccd4bc1e5f9b585bfd753ca45e2748&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_02ff735119f8381ad21c29d66530aa59.setContent(html_83ccd4bc1e5f9b585bfd753ca45e2748);
#
#
#
#         marker_a29957b3cb12cef288de6691298baf34.bindPopup(popup_02ff735119f8381ad21c29d66530aa59)
#         ;
#
#
#
#
#             var marker_b8156ec75c16365531225a38a804f697 = L.marker(
#                 [20.96972, -89.62272],
#                 {}
#             ).addTo(map_2897a4e796046a5f3c4a43e05caaa9bb);
#
#
#             var icon_d7f497c2ba80d2fb627155e77ecc9192 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;crosshairs&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b8156ec75c16365531225a38a804f697.setIcon(icon_d7f497c2ba80d2fb627155e77ecc9192);
#
#
#         var popup_c11b98e0a48f7d6c37e871e3fb7bee29 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f81b0c4c4cc60db364bc8733f1578025 = $(`&lt;div id=&quot;html_f81b0c4c4cc60db364bc8733f1578025&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_c11b98e0a48f7d6c37e871e3fb7bee29.setContent(html_f81b0c4c4cc60db364bc8733f1578025);
#
#
#
#         marker_b8156ec75c16365531225a38a804f697.bindPopup(popup_c11b98e0a48f7d6c37e871e3fb7bee29)
#         ;
#
#
#
#
#             marker_b8156ec75c16365531225a38a804f697.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9f5452c5ae6feafe76e32e85e778d338 = L.marker(
#                 [20.94167, -89.59466],
#                 {}
#             ).addTo(map_2897a4e796046a5f3c4a43e05caaa9bb);
#
#
#             var icon_5840ad1aa22c32e8b810e8e0cc0180f3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9f5452c5ae6feafe76e32e85e778d338.setIcon(icon_5840ad1aa22c32e8b810e8e0cc0180f3);
#
#
#         var popup_abd1638941e0fa298332dd89624f9a57 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b6531eb2c2f2ef275fd6d3c477a9948 = $(`&lt;div id=&quot;html_5b6531eb2c2f2ef275fd6d3c477a9948&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_abd1638941e0fa298332dd89624f9a57.setContent(html_5b6531eb2c2f2ef275fd6d3c477a9948);
#
#
#
#         marker_9f5452c5ae6feafe76e32e85e778d338.bindPopup(popup_abd1638941e0fa298332dd89624f9a57)
#         ;
#
#
#
#
#             marker_9f54

# %% [markdown]
# # Estilo del mapa

# %% [markdown]
# El estilo predeterminado se encuentra con la opción ``OpenStreetMap``, pero tambien cuenta con ``Stamen Terrain``, ``Stamen Toner``, ``Mapbox Bright``,  ``Mapbox Control Room`` y otros (https://deparkes.co.uk/2016/06/10/folium-map-tiles/).

# %% [markdown]
# ###  Stamen Toner

# %%
# Mapa de base
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12,  tiles ='Stamen Toner')
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red',icon='none') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='crosshairs')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='camera')   ).add_to(mapa)

folium.Circle(
    radius=500,
    location=[20.956972, -89.62272],
    popup='Sur',
    color='crimson',
    fill=False,
).add_to(mapa)

folium.Circle(
    location=[20.996972, -89.62272],
    radius=1500,
    popup='Norte',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16afadfc976396863d9c1f33ecd069aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16afadfc976396863d9c1f33ecd069aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16afadfc976396863d9c1f33ecd069aa = L.map(
#                 &quot;map_16afadfc976396863d9c1f33ecd069aa&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0683efa4099252d39240438dffce0200 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_16afadfc976396863d9c1f33ecd069aa);
#
#
#             var marker_46c1c6cce32a20e8b7242078f15c0594 = L.marker(
#                 [21.04829, -89.64025],
#                 {}
#             ).addTo(map_16afadfc976396863d9c1f33ecd069aa);
#
#
#             var icon_76d0b32e03ac65288b4a545d4780c1f0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;none&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_46c1c6cce32a20e8b7242078f15c0594.setIcon(icon_76d0b32e03ac65288b4a545d4780c1f0);
#
#
#         var popup_92d6a3769de4707b33e079fbb3944ee9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_654f741385ede7bd7f73d9ca71c7a6a8 = $(`&lt;div id=&quot;html_654f741385ede7bd7f73d9ca71c7a6a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_92d6a3769de4707b33e079fbb3944ee9.setContent(html_654f741385ede7bd7f73d9ca71c7a6a8);
#
#
#
#         marker_46c1c6cce32a20e8b7242078f15c0594.bindPopup(popup_92d6a3769de4707b33e079fbb3944ee9)
#         ;
#
#
#
#
#             var marker_86fc19637a8781b6525b01663a0f995d = L.marker(
#                 [20.96972, -89.62272],
#                 {}
#             ).addTo(map_16afadfc976396863d9c1f33ecd069aa);
#
#
#             var icon_7b998183ed5b379a3b53be32752510d3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;crosshairs&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_86fc19637a8781b6525b01663a0f995d.setIcon(icon_7b998183ed5b379a3b53be32752510d3);
#
#
#         var popup_db267d208a1a869e3b0fdcc57ae23808 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53f46e019d8cec92939b62bb1b70444c = $(`&lt;div id=&quot;html_53f46e019d8cec92939b62bb1b70444c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_db267d208a1a869e3b0fdcc57ae23808.setContent(html_53f46e019d8cec92939b62bb1b70444c);
#
#
#
#         marker_86fc19637a8781b6525b01663a0f995d.bindPopup(popup_db267d208a1a869e3b0fdcc57ae23808)
#         ;
#
#
#
#
#             marker_86fc19637a8781b6525b01663a0f995d.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1b3ba11ba0bc261e17728af90f15cfd6 = L.marker(
#                 [20.94167, -89.59466],
#                 {}
#             ).addTo(map_16afadfc976396863d9c1f33ecd069aa);
#
#
#             var icon_0d858c3caa6cd32d3b5f267be1bc6c38 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1b3ba11ba0bc261e17728af90f15cfd6.setIcon(icon_0d858c3caa6cd32d3b5f267be1bc6c38);
#
#
#         var popup_350d374fa4985e0a5bb11adaa89eb252 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1aec055c160402ad8fa0d70c94924fb7 = $(`&lt;div id=&quot;html_1aec055c160402ad8fa0d70c94924fb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];

# %% [markdown]
# ### Mapbox Bright

# %%
# Mapa de base
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12,  tiles ='Stamen Terrain')
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red',icon='none') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='crosshairs')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='camera')   ).add_to(mapa)

folium.Circle(
    radius=500,
    location=[20.956972, -89.62272],
    popup='Sur',
    color='crimson',
    fill=False,
).add_to(mapa)

folium.Circle(
    location=[20.996972, -89.62272],
    radius=1500,
    popup='Norte',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f38ed470805a2d21411d95612bcfab78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f38ed470805a2d21411d95612bcfab78&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f38ed470805a2d21411d95612bcfab78 = L.map(
#                 &quot;map_f38ed470805a2d21411d95612bcfab78&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e5301230f66ef34ec45d53eae0c3bbf = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f38ed470805a2d21411d95612bcfab78);
#
#
#             var marker_572f7269866d29a92efe4c9d5536922d = L.marker(
#                 [21.04829, -89.64025],
#                 {}
#             ).addTo(map_f38ed470805a2d21411d95612bcfab78);
#
#
#             var icon_0e997868c54da5b428e4f0dbafb1d5f8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;none&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_572f7269866d29a92efe4c9d5536922d.setIcon(icon_0e997868c54da5b428e4f0dbafb1d5f8);
#
#
#         var popup_4f593d6eb8a9a4ad1cd0240ba446b6a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b3b2b7ac066da4f00ca6a31fc78eb44 = $(`&lt;div id=&quot;html_2b3b2b7ac066da4f00ca6a31fc78eb44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_4f593d6eb8a9a4ad1cd0240ba446b6a4.setContent(html_2b3b2b7ac066da4f00ca6a31fc78eb44);
#
#
#
#         marker_572f7269866d29a92efe4c9d5536922d.bindPopup(popup_4f593d6eb8a9a4ad1cd0240ba446b6a4)
#         ;
#
#
#
#
#             var marker_9ca945d5da327383ccd002778f623e1c = L.marker(
#                 [20.96972, -89.62272],
#                 {}
#             ).addTo(map_f38ed470805a2d21411d95612bcfab78);
#
#
#             var icon_913eb31d7d3ebd8c1f796cfc97bbde08 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;crosshairs&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9ca945d5da327383ccd002778f623e1c.setIcon(icon_913eb31d7d3ebd8c1f796cfc97bbde08);
#
#
#         var popup_5b47977289ecea4ce1c5e13279475b90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c9d1aed1331d527be824660e6e9e5546 = $(`&lt;div id=&quot;html_c9d1aed1331d527be824660e6e9e5546&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_5b47977289ecea4ce1c5e13279475b90.setContent(html_c9d1aed1331d527be824660e6e9e5546);
#
#
#
#         marker_9ca945d5da327383ccd002778f623e1c.bindPopup(popup_5b47977289ecea4ce1c5e13279475b90)
#         ;
#
#
#
#
#             marker_9ca945d5da327383ccd002778f623e1c.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b895ea753a9b69882c896fe649ee5a70 = L.marker(
#                 [20.94167, -89.59466],
#                 {}
#             ).addTo(map_f38ed470805a2d21411d95612bcfab78);
#
#
#             var icon_1869555925611ef25226a26726f601ef = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b895ea753a9b69882c896fe649ee5a70.setIcon(icon_1869555925611ef25226a26726f601ef);
#
#
#         var popup_2e1aa21614cdc88f27ebe051f0e49ede = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c01136c97a2e342e6766c29fff02b2bd = $(`&lt;div id=&quot;html_c01136c97a2e342e6766c29fff02b2bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
