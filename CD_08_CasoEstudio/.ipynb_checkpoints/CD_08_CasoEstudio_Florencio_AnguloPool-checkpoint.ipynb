# %% [markdown]
# <center><h1 style="font-size:2em;color:#2467C0"> Ejercicio  </h1></center>
#
# ## Analizar con herramientas de pandas las bases de datos:
# * Covid
# * Incendios
# * Escuelas de Jalisco
# * Juegos olimpicos
# * Indicador de pobreza
#
# **Realizar 5 analisis en cada uno de los archivos. Describir el resultado**

# %%
import csv
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # Covid

# %%
df_covid = pd.read_csv('Datos/Covid_2020/200419COVID19MEXICO.csv')
df_covid#.head()
# Out:
#       FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0              2020-04-19      09e8dc       2       9          15     1
# 1              2020-04-19      1dd782       2      12           9     1
# 2              2020-04-19      0efbaf       2       9          28     2
# 3              2020-04-19      0e8ab4       2      12           9     2
# 4              2020-04-19      013a6c       1       3          15     2
# ...                   ...         ...     ...     ...         ...   ...
# 49565          2020-04-19      04da81       2      12          21     1
# 49566          2020-04-19      0cc924       1       4          30     1
# 49567          2020-04-19      145db8       1       4          30     2
# 49568          2020-04-19      17eb11       1      12          21     1
# 49569          2020-04-19      02242c       2      12          24     1
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# ...

# %% [markdown]
# ### Análisis 1
# <li> Seleccione todas las filas para pacientas masculinos y calcule la edad media. Hacer para las pacientes femeninas.</li>

# %%
df_covidH = df_covid[(df_covid['SEXO'] == 1 ) ]
df_covidM = df_covid[(df_covid['SEXO'] == 2 ) ]

# %%
df_covidH['EDAD'].mean()
# Out:
# 40.54916086130462

# %%
df_covidM['EDAD'].mean()
# Out:
# 41.353657533119396

# %% [markdown]
# ### Análisis 2
# <li> Graficar la frecuencia de edades de los hombres y mujeres

# %%
df_covidH['EDAD'].plot(kind='hist', title="frecuencia de edades de los hombres")
# Out:
# <Axes: title={'center': 'frecuencia de edades de los hombres'}, ylabel='Frequency'>

# %%
df_covidM['EDAD'].plot(kind='hist', title="frecuencia de edades de las mujeres")
# Out:
# <Axes: title={'center': 'frecuencia de edades de los hombres'}, ylabel='Frequency'>

# %%
df_covidH.plot.pie(y='DIABETES', figsize=(5, 5))#['DIABETES']#.plot(kind='hist', title="frecuencia de edades de los hombres")

# %%
# Out:
# FECHA_ACTUALIZACION     object
# ID_REGISTRO             object
# ORIGEN                   int64
# SECTOR                   int64
# ENTIDAD_UM               int64
# SEXO                     int64
# ENTIDAD_NAC              int64
# ENTIDAD_RES              int64
# MUNICIPIO_RES          float64
# TIPO_PACIENTE            int64
# FECHA_INGRESO           object
# FECHA_SINTOMAS          object
# FECHA_DEF               object
# INTUBADO                 int64
# NEUMONIA                 int64
# EDAD                     int64
# NACIONALIDAD             int64
# EMBARAZO                 int64
# HABLA_LENGUA_INDIG       int64
# DIABETES                 int64
# EPOC                     int64
# ASMA                     int64
# INMUSUPR                 int64
# HIPERTENSION             int64
# OTRA_COM                 int64
# CARDIOVASCULAR           int64
# OBESIDAD                 int64
# RENAL_CRONICA            int64
# TABAQUISMO               int64
# OTRO_CASO                int64
# ...

# %%
# Out:
#              ORIGEN        SECTOR    ENTIDAD_UM          SEXO   ENTIDAD_NAC  \
# count  49570.000000  49570.000000  49570.000000  49570.000000  49570.000000
# mean       1.603248      8.602522     14.712124      1.490337     35.098971
# std        0.489229      3.802911      8.122476      0.499912     34.728889
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        1.000000      4.000000      9.000000      1.000000     14.000000
# 50%        2.000000     12.000000     14.000000      1.000000     19.000000
# 75%        2.000000     12.000000     20.000000      2.000000     30.000000
# max        2.000000     13.000000     32.000000      2.000000     99.000000
#
#         ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE      INTUBADO      NEUMONIA  \
# count  49570.000000   49561.000000   49570.000000  49570.000000  49570.000000
# mean      14.919205      35.851254       1.236232     74.555094      1.857051
# ...

# %%
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'DIABETES',
#        'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'RESULTADO', 'MIGRANTE', 'PAIS_NACIONALIDAD',
#        'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %% [markdown]
# # Incendios

# %%
df_incendios = pd.read_csv('Datos/Incendios/Historico_IncendiosForestales_1970-2022.csv')
df_incendios.head(5)
# Out:
#   Gerencia De Manejo del Fuego, Diciembre 2022          Unnamed: 1  \
# 0                                          Año  Entidad Federativa
# 1                                         1970           Chihuahua
# 2                                         1970             Chiapas
# 3                                         1970          Guanajuato
# 4                                         1970              México
#
#                          Unnamed: 2                Unnamed: 3 Unnamed: 4
# 0  Cantidad de Incendios Forestales  Superficie quemada en ha     Región
# 1                               301                     50088      Norte
# 2                                97                     15395    Sureste
# 3                                10                     12801  Occidente
# 4                               906                     11514     Centro

# %%
df_incendios.dtypes
# Out:
# Gerencia De Manejo del Fuego, Diciembre 2022    object
# Unnamed: 1                                      object
# Unnamed: 2                                      object
# Unnamed: 3                                      object
# Unnamed: 4                                      object
# dtype: object

# %%
df_incendios.describe()
# Out:
#        Gerencia De Manejo del Fuego, Diciembre 2022 Unnamed: 1 Unnamed: 2  \
# count                                          1697       1697       1697
# unique                                           54         33        542
# top                                            1996    Hidalgo          0
# freq                                             32         53         49
#
#        Unnamed: 3 Unnamed: 4
# count        1697       1697
# unique       1511          7
# top             0     Centro
# freq           49        530

# %%
df_incendios.columns
# Out:
# Index(['Gerencia De Manejo del Fuego, Diciembre 2022', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],
#       dtype='object')

# %% [markdown]
# # Escuelas de Jalisco

# %%
df_Ejalisco = pd.read_csv('Datos/EscuelasJalisco/cct_estadistica.csv', encoding='latin-1')
df_Ejalisco.head(5)
# Out:
#      CLAVE CT                    NOM TURNO                  NOMBRE CT  \
# 0  14DPR3480S                   VESPERTINO  MIGUEL HIDALGO Y COSTILLA
# 1  14DPR2780I                     MATUTINO        CONSTITUCION DEL 57
# 2  14DPR1553G  CONTINUO (JORNADA AMPLIADA)  MIGUEL HIDALGO Y COSTILLA
# 3  14SES0104Q                     MATUTINO               NIOS HEROES
# 4  14EJN0826I                   VESPERTINO        EVA GONZALEZ BLANCO
#
#                         DOMICILIO  LOCALIDAD INEGI       NOMBRE LOCALIDAD  \
# 0                    RIO SANTIAGO                1        TIZAPAN EL ALTO
# 1                        CONOCIDO               54         MESA DE MENDEZ
# 2                        CONOCIDO               31                DOLORES
# 3              ALVARO OBREGON 115              280  SANTA MARIA DEL VALLE
# 4  MARCELINO GARCIA BARRAGAN 1954                1            GUADALAJARA
#
#   NOMBRE COLONIA  MUNICIPIO NOMBRE MUNICIPIO SOSTENIMIENTO  ... DOCENTES  \
# ...

# %%
df_Ejalisco.dtypes
# Out:
# CLAVE CT                                  object
# NOM TURNO                                 object
# NOMBRE CT                                 object
# DOMICILIO                                 object
# LOCALIDAD INEGI                            int64
#  NOMBRE LOCALIDAD                         object
# NOMBRE COLONIA                            object
# MUNICIPIO                                  int64
# NOMBRE MUNICIPIO                          object
# SOSTENIMIENTO                             object
# NIVEL                                     object
# PROGRAMA                                  object
# HOMBRES 1¡                                 int64
# MUJERES 1¡                                 int64
# TOTAL 1¡                                   int64
# HOMBRES 2¡                                 int64
# MUJERES 2¡                                 int64
# TOTAL 2¡                                   int64
# HOMBRES 3¡                                 int64
# ...

# %%
df_Ejalisco.describe()
# Out:
#        LOCALIDAD INEGI     MUNICIPIO    HOMBRES 1¡    MUJERES 1¡  \
# count     14018.000000  14018.000000  14018.000000  14018.000000
# mean         69.183621     68.894421     14.384292     13.736767
# std         373.026706     36.053656     27.833578     25.470229
# min           1.000000      1.000000      0.000000      0.000000
# 25%           1.000000     39.000000      0.000000      0.000000
# 50%           3.000000     67.000000      4.000000      4.000000
# 75%          51.000000     98.000000     16.000000     15.000000
# max        9503.000000    125.000000    773.000000    412.000000
#
#            TOTAL 1¡    HOMBRES 2¡    MUJERES 2¡      TOTAL 2¡    HOMBRES 3¡  \
# count  14018.000000  14018.000000  14018.000000  14018.000000  14018.000000
# mean      28.121059     17.870238     17.392852     35.263090     17.290555
# std       52.060523     24.878830     24.401495     48.270267     23.177131
# ...

# %%
df_Ejalisco.columns
# Out:
# Index(['CLAVE CT', 'NOM TURNO', 'NOMBRE CT', 'DOMICILIO', 'LOCALIDAD INEGI',
#        ' NOMBRE LOCALIDAD', 'NOMBRE COLONIA', 'MUNICIPIO', 'NOMBRE MUNICIPIO',
#        'SOSTENIMIENTO', 'NIVEL', 'PROGRAMA', 'HOMBRES 1¡', 'MUJERES 1¡',
#        'TOTAL 1¡', 'HOMBRES 2¡', 'MUJERES 2¡', 'TOTAL 2¡', 'HOMBRES 3¡',
#        'MUJERES 3¡', 'TOTAL 3¡', 'HOMBRES 4¡', 'MUJERES 4¡', 'TOTAL 4¡',
#        'HOMBRES 5¡', 'MUJERES 5¡', 'TOTAL 5¡', 'HOMBRES 6¡', 'MUJERES 6¡',
#        'TOTAL 6¡', 'HOMBRES TOTAL', 'MUJERES TOTAL', 'MATRICULA TOTAL',
#        'DOCENTES', 'GRUPOS', 'DOCENETE EDUCACION FISICA',
#        'DOCENTE ACTIVIDADES ARTISTICAS', 'DOCENTE ACTIVIDADES TECNONOLOGICAS',
#        'DOCENTE DE IDIOMAS', 'PERSONAL DE ADMINISTRATIVO Y SERVICIOS',
#        'DIRECTOR CON GRUPO', 'DIRECTOR SIN GRUPO', 'TOTAL DE PERSONAL'],
#       dtype='object')

# %% [markdown]
# # Juegos olimpicos

# %%
df_olimpic = pd.read_csv('Datos/Olimpiadas/athlete_events.csv')
df_olimpic.head(5)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df_olimpic.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object
