# %% [markdown]
# # Ejemplo de notebook Jupyter

# %% [markdown]
# ## 1. Cargar los datos

# %%
# Cargar las biblioteca Pandas con el alias 'pd’
# Cargar las biblioteca Matplotlib con el alias ‘plt’
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# En este notebook se utilizará la gráfica de la cronología de los precios minoristas de gasolina de todas las formulaciones en EE. UU. dede 1992 hasta 2022
# *Fuente:* https://www.eia.gov/dnav/pet/hist/LeafHandler.ashx?n=pet&s=emm_epmr_pte_nus_dpg&f=a
# ![Imagen de costos de celular](figuras/img_gasUSA_cost.png)

# %% [markdown]
# En este notebook se utilizará la gráfica de la cronología de los precios de los teléfonos móviles a lo largo de los años
# *Fuente:* https://www.ooma.com/home-phone/cell-phone-cost-comparison/
# <img src="figuras/img_gasUSA_cost.png" width=250/>

# %%
# Leer datos del archivo Gasoline_Prices.csv
data = pd.read_csv ("datos/Gasoline_Prices.csv")

# %%
# Vista previa de las primeras 5 líneas de los datos cargados
data.head ()
# Out:
#    Year  Gasoline Prices
# 0  2022            3.951
# 1  2021            3.008
# 2  2020            2.168
# 3  2019            2.604
# 4  2018            2.719

# %% [markdown]
# ## 2. Graficar los datos

# %%
#Graficamos las variables
data.plot(x ='Year', y='Gasoline Prices', kind = 'line', figsize=(25,6))
plt.show()
