# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datos/german_train_test.txt', delim_whitespace=True)
df.head(5)
# Out:
#    1   6  4  12  5  5.1  3  4.1  1.1  67  ...  0  0.1  1.4  0.2  0.3  1.5  \
# 0  2  48  2  60  1    3  2    2    1  22  ...  0    0    1    0    0    1
# 1  4  12  4  21  1    4  3    3    1  49  ...  0    0    1    0    0    1
# 2  1  42  2  79  1    4  3    4    2  45  ...  0    0    0    0    0    0
# 3  1  24  3  49  1    3  3    4    4  53  ...  1    0    1    0    0    0
# 4  4  36  2  91  5    3  3    4    4  35  ...  0    0    1    0    0    0
#
#    0.4  0.5  1.6  1.7
# 0    0    0    1    2
# 1    0    1    0    1
# 2    0    0    1    1
# 3    0    0    1    2
# 4    0    1    0    1
#
# [5 rows x 25 columns]

# %%
df.dtypes
# Out:
# 1      int64
# 6      int64
# 4      int64
# 12     int64
# 5      int64
# 5.1    int64
# 3      int64
# 4.1    int64
# 1.1    int64
# 67     int64
# 3.1    int64
# 2      int64
# 1.2    int64
# 2.1    int64
# 1.3    int64
# 0      int64
# 0.1    int64
# 1.4    int64
# 0.2    int64
# 0.3    int64
# 1.5    int64
# 0.4    int64
# 0.5    int64
# 1.6    int64
# 1.7    int64
# dtype: object

# %%
df.corr(method='pearson').round(2)
# Out:
#         1     6     4    12     5   5.1     3   4.1   1.1    67  ...     0  \
# 1    1.00 -0.07  0.20 -0.05  0.22  0.10  0.04 -0.04 -0.03  0.05  ... -0.08
# 6   -0.07  1.00 -0.07  0.63  0.05  0.07  0.02  0.03  0.29 -0.03  ... -0.09
# 4    0.20 -0.07  1.00 -0.05  0.04  0.13  0.03  0.05 -0.04  0.15  ...  0.06
# 12  -0.05  0.63 -0.05  1.00  0.08 -0.01 -0.01  0.03  0.32  0.02  ... -0.04
# 5    0.22  0.05  0.04  0.08  1.00  0.11  0.00  0.09  0.02  0.08  ... -0.01
# 5.1  0.10  0.07  0.13 -0.01  0.11  1.00  0.10  0.25  0.10  0.26  ... -0.02
# 3    0.04  0.02  0.03 -0.01  0.00  0.10  1.00 -0.03 -0.02  0.02  ...  0.02
# 4.1 -0.04  0.03  0.05  0.03  0.09  0.25 -0.03  1.00  0.14  0.27  ...  0.02
# 1.1 -0.03  0.29 -0.04  0.32  0.02  0.10 -0.02  0.14  1.00  0.09  ... -0.02
# 67   0.05 -0.03  0.15  0.02  0.08  0.26  0.02  0.27  0.09  1.00  ...  0.07
# 3.1  0.05 -0.06  0.12 -0.02 -0.01 -0.03 -0.05 -0.00 -0.08 -0.03  ...  0.02
# ...

# %%
df.columns
# Out:
# Index(['1', '6', '4', '12', '5', '5.1', '3', '4.1', '1.1', '67', '3.1', '2',
#        '1.2', '2.1', '1.3', '0', '0.1', '1.4', '0.2', '0.3', '1.5', '0.4',
#        '0.5', '1.6', '1.7'],
#       dtype='object')

# %%
#Create names for the columns 
#column_names=['existingcheckingstatus', 'duration', 'credithistory', 'purpose', 'creditamount', 
#         'savings', 'employmentlength', 'installmentrate', 'marriagesex', 'otherdebtors', 
#         'presentresidencelength', 'property', 'age', 'otherinstallmentplans', 'housing', 
 #        'existingcredits', 'job', 'peopleliableno', 'telephone', 'foreignworker', 'classification']

# %%
#df=pd.DataFrame(data, columns=column_names)

# %%
df
# Out:
#      1   6  4  12  5  5.1  3  4.1  1.1  67  ...  0  0.1  1.4  0.2  0.3  1.5  \
# 0    2  48  2  60  1    3  2    2    1  22  ...  0    0    1    0    0    1
# 1    4  12  4  21  1    4  3    3    1  49  ...  0    0    1    0    0    1
# 2    1  42  2  79  1    4  3    4    2  45  ...  0    0    0    0    0    0
# 3    1  24  3  49  1    3  3    4    4  53  ...  1    0    1    0    0    0
# 4    4  36  2  91  5    3  3    4    4  35  ...  0    0    1    0    0    0
# ..  ..  .. ..  .. ..  ... ..  ...  ...  ..  ... ..  ...  ...  ...  ...  ...
# 894  4  36  3  89  5    4  3    2    3  31  ...  0    1    1    0    0    1
# 895  1  21  2  26  1    2  2    4    2  28  ...  0    0    1    0    1    0
# 896  4  12  4  16  4    4  2    2    2  35  ...  0    0    1    0    0    1
# 897  4  15  2  22  5    4  2    4    1  33  ...  0    0    1    0    1    0
# 898  1  18  2  42  1    3  3    3    3  42  ...  0    0    0    1    0    1
#
#      0.4  0.5  1.6  1.7
# 0      0    0    1    2
# ...

# %%
#read_file = pd.read_csv (r'datos/german_train_test.txt')
#read_file.to_csv (r'datos/german_train_test.csv', index=None)

# %%
df.shape
# Out:
# (899, 25)

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'1'}>,
#         <AxesSubplot:title={'center':'6'}>,
#         <AxesSubplot:title={'center':'4'}>,
#         <AxesSubplot:title={'center':'12'}>,
#         <AxesSubplot:title={'center':'5'}>],
#        [<AxesSubplot:title={'center':'5.1'}>,
#         <AxesSubplot:title={'center':'3'}>,
#         <AxesSubplot:title={'center':'4.1'}>,
#         <AxesSubplot:title={'center':'1.1'}>,
#         <AxesSubplot:title={'center':'67'}>],
#        [<AxesSubplot:title={'center':'3.1'}>,
#         <AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'1.2'}>,
#         <AxesSubplot:title={'center':'2.1'}>,
#         <AxesSubplot:title={'center':'1.3'}>],
#        [<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'0.1'}>,
#         <AxesSubplot:title={'center':'1.4'}>,
#         <AxesSubplot:title={'center':'0.2'}>,
#         <AxesSubplot:title={'center':'0.3'}>],
#        [<AxesSubplot:title={'center':'1.5'}>,
# ...

# %%
from pandas.plotting import scatter_matrix
atributos = [ '6', '12', '67' ]
scatter_matrix( df[ atributos] , figsize=(12,8) )
# Out:
# array([[<AxesSubplot:xlabel='6', ylabel='6'>,
#         <AxesSubplot:xlabel='12', ylabel='6'>,
#         <AxesSubplot:xlabel='67', ylabel='6'>],
#        [<AxesSubplot:xlabel='6', ylabel='12'>,
#         <AxesSubplot:xlabel='12', ylabel='12'>,
#         <AxesSubplot:xlabel='67', ylabel='12'>],
#        [<AxesSubplot:xlabel='6', ylabel='67'>,
#         <AxesSubplot:xlabel='12', ylabel='67'>,
#         <AxesSubplot:xlabel='67', ylabel='67'>]], dtype=object)
