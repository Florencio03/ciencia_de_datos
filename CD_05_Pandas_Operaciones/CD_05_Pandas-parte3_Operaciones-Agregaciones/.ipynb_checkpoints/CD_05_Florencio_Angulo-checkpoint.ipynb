# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/logo_ciencia_datos.png">

# %% [markdown]
# <center><h1 style="font-size:2em;color:#2467C0"> Pandas -Parte 3  </h1></center>
#
# <center><h2 style="font-size:2em;color:#840700">  Pandas - Operaciones y agregaciones  </h4></center>
#
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="figuras/pandas3.png" align="left" style="width:500px"/></td>
# <td>
#
# * **Wes McKinney**, empezó a desarrollar Pandas en el año 2008 mientras trabajaba en *AQR Capital* [https://www.aqr.com/] por la necesidad que tenía de una herramienta flexible de alto rendimiento para realizar análisis cuantitativos en datos financieros.
# * Antes de dejar AQR convenció a la administración de la empresa de distribuir esta biblioteca bajo licencia de código abierto.
# * **Pandas** es un acrónimo de **PANel DAta analysiS**
#
#
# <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# # Librerías
#
# Cargando las bibliotecas que necesitamos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Operaciones de datos en Pandas

# %% [markdown]
# Parte de las características esenciales de **NumPy** es la capacidad de realizar operaciones rápidas de elementos, tanto con aritmética básica (suma, resta, multiplicación, etc.) como con operaciones más sofisticadas (funciones trigonométricas, funciones exponenciales y logarítmicas, etc.).
# Pandas hereda gran parte de esta funcionalidad de **NumPy** y las _**ufuncs**_ que fueron presentadas en lecciones pasadas son clave para esto.
#
# Sin embargo, **Pandas** incluye un par de características  extras que serán  útiles: para operaciones de negación y trigonométricas, estas _**ufuncs**_  preservarán las etiquetas de índice y columna en la salida, y para operaciones como la suma y la multiplicación, **Pandas** automáticamente *alineará índices*.
# Esto significa que mantener el contexto de los datos y combinar datos de diferentes fuentes, ambas tareas potencialmente propensas a errores con arreglos de **NumPy** sin procesar, se vuelven esencialmente infalibles con **Pandas**.

# %%
poblacion = pd.Series({'Belgica':11.3, 'Francia':64.3, 'Alemania':81.3,
                       'Holanda':16.9, 'Inglaterra':64.9,'Argentina':12.1,'Mexico':103.2})

# %%
data = {'pias': ['Belgica', 'Francia', 'Alemania', 'Holanda', 'Inglaterra','Argentina','Mexico'],
        'poblacion': [11.3, 64.3, 81.3, 16.9, 64.9, 12.1,103.2],
        'area': [30510, 671308, 357050, 41526, 244820,300163,1960573],
        'capital': ['Bruselas', 'Paris', 'Berlin', 'Amsterdam', 'Londres','Buenos Aires','Ciudad de Mexico']}
paises = pd.DataFrame(data)

# %%
#mostrar el dataframe
paises.head()
# Out:
#          pias  poblacion    area    capital
# 0     Belgica       11.3   30510   Bruselas
# 1     Francia       64.3  671308      Paris
# 2    Alemania       81.3  357050     Berlin
# 3     Holanda       16.9   41526  Amsterdam
# 4  Inglaterra       64.9  244820    Londres

# %% [markdown]
# ## Los "nuevos" conceptos

# %% [markdown]
# Al igual que con loss arreglos de numpy, muchas operaciones son con elementos:

# %%
#Dividir entre 100 los valores de la poblacion en la serie poblacion
poblacion/100
# Out:
# Belgica       0.113
# Francia       0.643
# Alemania      0.813
# Holanda       0.169
# Inglaterra    0.649
# Argentina     0.121
# Mexico        1.032
# dtype: float64

# %%
#Encontrar la densidad poblacional en el DataFrame paises
paises['densidad'] = paises['poblacion']/paises['area']
paises
# Out:
#          pias  poblacion     area           capital  densidad
# 0     Belgica       11.3    30510          Bruselas  0.000370
# 1     Francia       64.3   671308             Paris  0.000096
# 2    Alemania       81.3   357050            Berlin  0.000228
# 3     Holanda       16.9    41526         Amsterdam  0.000407
# 4  Inglaterra       64.9   244820           Londres  0.000265
# 5   Argentina       12.1   300163      Buenos Aires  0.000040
# 6      Mexico      103.2  1960573  Ciudad de Mexico  0.000053

# %%
#Obtener el logaritmo del valor de la población en el DataFrame countries
np.log(paises['poblacion'])
# Out:
# 0    2.424803
# 1    4.163560
# 2    4.398146
# 3    2.827314
# 4    4.172848
# 5    2.493205
# 6    4.636669
# Name: poblacion, dtype: float64

# %%
#Agregar los valores de la evaluación del logaritmo como una nueva columna "log_poblacion"
paises['Log_poblacion'] = np.log(paises['poblacion'])
paises
# Out:
#          pias  poblacion     area           capital  densidad  Log_poblacion
# 0     Belgica       11.3    30510          Bruselas  0.000370       2.424803
# 1     Francia       64.3   671308             Paris  0.000096       4.163560
# 2    Alemania       81.3   357050            Berlin  0.000228       4.398146
# 3     Holanda       16.9    41526         Amsterdam  0.000407       2.827314
# 4  Inglaterra       64.9   244820           Londres  0.000265       4.172848
# 5   Argentina       12.1   300163      Buenos Aires  0.000040       2.493205
# 6      Mexico      103.2  1960573  Ciudad de Mexico  0.000053       4.636669

# %%
#Mostrar las columnas del  DataFrame paises
paises.columns
# Out:
# Index(['pias', 'poblacion', 'area', 'capital', 'densidad', 'Log_poblacion'], dtype='object')

# %%
#Mostrar cuales de ellos tienen una población mayor a los 40 (millones)
paises['poblacion'] > 40 #primero se aplica una mascara
#Mostrar el dataframe solo con las columnas 'pais'  y 'capital'
paises[ paises['poblacion'] > 40 ] #Se aplica la masccara en el DataFrma
# Out:
#          pias  poblacion     area           capital  densidad  Log_poblacion
# 1     Francia       64.3   671308             Paris  0.000096       4.163560
# 2    Alemania       81.3   357050            Berlin  0.000228       4.398146
# 4  Inglaterra       64.9   244820           Londres  0.000265       4.172848
# 6      Mexico      103.2  1960573  Ciudad de Mexico  0.000053       4.636669

# %%
#Mostrar el dataframe solo con las columnas 'pais'  y 'capital'
paises[['pias', 'capital']]
#paises[['país', 'capital']]
# Out:
#          pias           capital
# 0     Belgica          Bruselas
# 1     Francia             Paris
# 2    Alemania            Berlin
# 3     Holanda         Amsterdam
# 4  Inglaterra           Londres
# 5   Argentina      Buenos Aires
# 6      Mexico  Ciudad de Mexico

# %% [markdown]
# Cuando requiere de una operación especial en los elementos puede hacerlo con ``apply(OPERACIÓN)``, en donde será necesario _definir la  operación_ a través de la función deseada

# %%
# Agregar una columna que indique si el país es pequeño o grande en población (>50). 
# Defina una función llamada etiqueta_poblacion que regrese la etiqueta

# %%
def etiqueta_poblacion(valor_poblacion):
    if valor_poblacion > 50:
        return 'grande'
    else:
        return 'pequeño'

# %%
 paises['poblacion'].apply( etiqueta_poblacion )
# Out:
# 0    pequeño
# 1     grande
# 2     grande
# 3    pequeño
# 4     grande
# 5    pequeño
# 6     grande
# Name: poblacion, dtype: object

# %%
#Agregar la columna etiqueta_poblacional con el resultado de aplicar la funcion etiqueta_poblacion
paises['etiqueta_poblacional'] = paises['poblacion'].apply( etiqueta_poblacion )
paises
# Out:
#          pias  poblacion     area           capital  densidad  Log_poblacion  \
# 0     Belgica       11.3    30510          Bruselas  0.000370       2.424803
# 1     Francia       64.3   671308             Paris  0.000096       4.163560
# 2    Alemania       81.3   357050            Berlin  0.000228       4.398146
# 3     Holanda       16.9    41526         Amsterdam  0.000407       2.827314
# 4  Inglaterra       64.9   244820           Londres  0.000265       4.172848
# 5   Argentina       12.1   300163      Buenos Aires  0.000040       2.493205
# 6      Mexico      103.2  1960573  Ciudad de Mexico  0.000053       4.636669
#
#   etiqueta_poblacional
# 0              pequeño
# 1               grande
# 2               grande
# 3              pequeño
# 4               grande
# 5              pequeño
# 6               grande

# %% [markdown]
# También es posible utilizar la función ``lambda``  para realizar operaciones rápidas.

# %%
# Encuentre el número de caracteres de las palabras en la columna capital 
def conteo (string):
     return len(string)
paises['capital'].apply( conteo )
# Out:
# 0     8
# 1     5
# 2     6
# 3     9
# 4     7
# 5    12
# 6    16
# Name: capital, dtype: int64

# %%
paises['capital'].apply( lambda string : len(string) )
# Out:
# 0     8
# 1     5
# 2     6
# 3     9
# 4     7
# 5    12
# 6    16
# Name: capital, dtype: int64

# %% [markdown]
# ## Agregaciones (reducciones)

# %% [markdown]
# Pandas proporciona un amplio conjunto de funciones de _**resumen**_ que operan en diferentes tipos de objetos de pandas (DataFrames y Series) y producen un valor único. Cuando se aplica a un *DataFrame*, el resultado se retorna como una Serie de Pandas (un valor para cada columna).

# %%
#Utilizando la Serie de poblacion, podemos encontrar su promedio usando mean():
poblacion.mean()
# Out:
# 50.57142857142857

# %%
#Aplicar la mediana al DataFrame paises
paises.median( numeric_only = True)
# Out:
# poblacion            64.300000
# area             300163.000000
# densidad              0.000228
# Log_poblacion         4.163560
# dtype: float64

# %%
#Podemos encontrar el pais con con area mas pequeña usando min():
paises.min( numeric_only = True)
# Out:
# poblacion           11.300000
# area             30510.000000
# densidad             0.000040
# Log_poblacion        2.424803
# dtype: float64

# %% [markdown]
# La siguiente tabla resume algunas otras agregaciones integradas de Pandas:
#
# | Aggregation              | Description                     |
# |--------------------------|---------------------------------|
# | ``count()``              | Total number of items           |
# | ``first()``, ``last()``  | First and last item             |
# | ``mean()``, ``median()`` | Mean and median                 |
# | ``min()``, ``max()``     | Minimum and maximum             |
# | ``std()``, ``var()``     | Standard deviation and variance |
# | ``mad()``                | Mean absolute deviation         |
# | ``prod()``               | Product of all items            |
# | ``sum()``                | Sum of all items                |
#
# Todos estos son funcionan en *DataFrames* y *Series*.

# %% [markdown]
# Hay una función de muy útil, ``describe()`` , que calcula varios parámetros estadísticos  para cada columna y devuelve el resultado.

# %%
 paises.describe()
# Out:
#         poblacion          area  densidad  Log_poblacion
# count    7.000000  7.000000e+00  7.000000       7.000000
# mean    50.571429  5.151357e+05  0.000208       3.588078
# std     37.112115  6.729440e+05  0.000150       0.962601
# min     11.300000  3.051000e+04  0.000040       2.424803
# 25%     14.500000  1.431730e+05  0.000074       2.660260
# 50%     64.300000  3.001630e+05  0.000228       4.163560
# 75%     73.100000  5.141790e+05  0.000318       4.285497
# max    103.200000  1.960573e+06  0.000407       4.636669

# %% [markdown]
# # Ejercicios con los datos del Titanic

# %% [markdown]
# Descripción de las columnas :
#
#     Survival - Supervivencia (0 = No; 1 = Si).
#     Pclass - Clase (1 = 1st; 2 = 2nd; 3 = 3rd)
#     Name - Nombre
#     Sex - Sexo
#     Age - Edad
#     Sibsp - Número de hermanos / cónyuges a bordo
#     Parch - Número de padres / niños a bordo
#     Ticket - Número de ticket
#     Fare - Tarifa
#     Cabin - Número de cabina
#     Embarked - Puerto de embarque (C = Cherbourg; Q = Queenstown; S = Southampton)

# %%
#Utilizar el archivo datos/titanic.csv
titanic_df = pd.read_csv('datos/titanic.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#muestre las primeras líneas del DataFrame
titanic_df.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S

# %%
#muestre las ultimas líneas  del DataFrame 
titanic_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#Obtenga el número de filas y columnas
titanic_df.shape
# Out:
# (891, 12)

# %%
#Muestre los histogramas de las variables numericas
titanic_df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'PassengerId'}>,
#         <AxesSubplot:title={'center':'Survived'}>,
#         <AxesSubplot:title={'center':'Pclass'}>],
#        [<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'SibSp'}>,
#         <AxesSubplot:title={'center':'Parch'}>],
#        [<AxesSubplot:title={'center':'Fare'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# <div class="alert alert-info">
#
# <b>EJERCICIO</b>:
#
#  <ul>
#   <li> Seleccione todas las filas para pasajeros masculinos y calcule la edad media de esos pasajeros. Hacer lo mismo con las pasajeras.</li>
# </ul>
# </div>

# %%
#Se puede definir un nuevo DataFrame solamente con elementos "male" en la columna de Sex
df_male = titanic_df[titanic_df['Sex'] == 'male']
df_male.head()
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0            1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4            5         0       3        Allen, Mr. William Henry  male  35.0
# 5            6         0       3                Moran, Mr. James  male   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7            8         0       3  Palsson, Master. Gosta Leonard  male   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S

# %%
#Se encuentra la media utilizando el nuevo DataFrame
df_male['Age'].mean()
# Out:
# 30.72664459161148

# %%
titanic_df[titanic_df['Sex'] == 'male']['Age'].mean()
# Out:
# 30.72664459161148

# %%
#Redondeando el valor anterior a dos decimales
round(titanic_df[titanic_df['Sex'] == 'male']['Age'].mean(), 2)
# Out:
# 30.73

# %%
#Para el segundo requerimiento se puede realizar todo en una sola linea
titanic_df[titanic_df['Sex'] == 'female']['Age'].mean()
# Out:
# 27.915708812260537

# %%
#Redondeando el valor anterior a dos decimales
round(titanic_df[titanic_df['Sex'] == 'female']['Age'].mean(), 2)
# Out:
# 27.92

# %% [markdown]
# <div class="alert alert-info">
#
# <b>EJERCICIO</b>:
#
#  <ul>
#   <li>¿Cuántos pasajeros mayores de 70 estaban en el Titanic?</li>
# </ul>
# </div>

# %%
#Se puede aplicar una máscara para seleccionar solamente a los pasajeros mayores a 70 años, 
#Al DataFrame resultante se cuentan las filas usando len()
df_age = titanic_df[titanic_df['Age'] > 70]
len(df_age )
#df_age.head()
# Out:
# 5

# %%
#Un segundo método es aplicar la función sum() a la máscara booleana, 
#Solamente se sumaran los elementos True
(titanic_df['Age'] > 70).sum()
# Out:
# 5

# %%
titanic_df [ titanic_df['Age'] > 70 ]['Age'].count()
# Out:
# 5

# %% [markdown]
# <div class="alert alert-info">
#
# <b>EJERCICIO</b>:
#
#  <ul>
#   <li>¿Seleccionar los pasajeros que tienen entre 30 y 40 años?</li>
# </ul>
# </div>

# %%
titanic_df [ (titanic_df['Age'] >30) & (titanic_df['Age']<40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 13            14         0       3
# 18            19         0       3
# ..           ...       ...     ...
# 867          868         0       1
# 872          873         0       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 4        0    373450   8.0500          NaN        S
# 13       5    347082  31.2750          NaN        S
# 18       0    345763  18.0000          NaN        S
# ..     ...       ...      ...          ...      ...
# 867      0  PC 17590  50.4958          A24        S
# 872      0       695   5.0000  B51 B53 B55        S
# 881      0    349257   7.8958          NaN        S
# 885      5    382652  29.1250          NaN        Q
# 890      0    370376   7.7500          NaN        Q
#
# [142 rows x 12 columns]

# %% [markdown]
# <div class="alert alert-info">
#
# <b>EJERCICIO</b>:
#
#  <ul>
#   <li> Divida la columna 'Name' y  extraiga la primera parte (el apellido) y agréguela como nueva columna 'Surname', para el resto del nombre agregarlo en una nueva columna llamada 'R-name'</li>
# </ul>
#
# <br>
# </div>

# %%
#Para la columna Surname se definirá una nueva función
def surname(x):
        name=x.split(',')
        return name[0]

# %%
#Ejemplo sin la funcion 
frase = 'hola mundo, hoy es un día nublado'
frase
Y = frase.split(',') 
X = frase.split(',')[0] # El [0] es para indicar el elemento de la lista que se desea
print(Y) #Lista creada
print(X) #elementon que se desea extraer
# Out:
# ['hola mundo', ' hoy es un día nublado']
# hola mundo

# %%
surname('hola mundo, hoy es un día nublado')
# Out:
# 'hola mundo'

# %%
#Aplicando la funcion en el DataFrame
titanic_df['Surname']=titanic_df['Name'].apply(surname)
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked    Surname
# 0        0         A/5 21171   7.2500   NaN        S     Braund
# 1        0          PC 17599  71.2833   C85        C    Cumings
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3        0            113803  53.1000  C123        S   Futrelle
# 4        0            373450   8.0500   NaN        S      Allen
# ..     ...               ...      ...   ...      ...        ...
# 886      0            211536  13.0000   NaN        S   Montvila
# 887      0            112053  30.0000   B42        S     Graham
# 888      2        W./C. 6607  23.4500   NaN        S   Johnston
# 889      0            111369  30.0000  C148        C       Behr
# 890      0            370376   7.7500   NaN        Q     Dooley
#
# [891 rows x 13 columns]

# %%
#Para la columna R-name utilizaremos una función lambda
titanic_df['R-name'] = titanic_df['Name'].apply( lambda x : x.split(',')[1] )
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0        0         A/5 21171   7.2500   NaN        S     Braund
# 1        0          PC 17599  71.2833   C85        C    Cumings
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3        0            113803  53.1000  C123        S   Futrelle
# 4        0            373450   8.0500   NaN        S      Allen
# ..     ...               ...      ...   ...      ...        ...
# 886      0            211536  13.0000   NaN        S   Montvila
# 887      0            112053  30.0000   B42        S     Graham
# 888      2        W./C. 6607  23.4500   NaN        S   Johnston
# 889      0            111369  30.0000  C148        C       Behr
# 890      0            370376   7.7500   NaN        Q     Dooley
#
#                                           R-name
# 0                                Mr. Owen Harris
# 1     Mrs. John Bradley (Florence Briggs Thayer)
# 2                                    Miss. Laina
# 3             Mrs. Jacques Heath (Lily May Peel)
# 4                              Mr. William Henry
# ..                                           ...
# 886                                  Rev. Juozas
# 887                         Miss. Margaret Edith
# 888               Miss. Catherine Helen "Carrie"
# 889                              Mr. Karl Howell
# 890                                  Mr. Patrick
#
# [891 rows x 14 columns]

# %% [markdown]
# <div class="alert alert-info">
#
# <b>EJERCICIO</b>:
#
#
# Agregar una nueva columna llamada “Categoria”, la cual tendrá como elementos las siguientes etiquetas segun el valor del ticket:
#
# * Si el valor es menor a 20, L -- Ticket -- Pclass -- Fare
# * Si el valor es mayor o igual a 20 pero menor a 50, M -- Ticket -- Pclass -- Fare
# * Si el valor es mayor o igual 50, H -- Ticket -- Pclass -- Fare
#
# Ejemplo:
# L--A/5 21171--3--7.25
#
# H--PC 17599--1--71.2833
#
# L--STON/O2. 3101282--3--7.925
#
# </div>

# %%
def tag( x ): # Cheack this part
    if ( x[0] < 20 ):
        return 'L-'+x[1]+ '-' +str(x[2]) + '-' + str(x[0])
    elif (20 <= x[0] and x[0] < 50):
        return 'M-'+x[1]+ '-' +str(x[2]) + '-' + str(x[0])
    elif (x[0] >= 50):
        return 'H-'+x[1]+ '-' +str(x[2]) + '-' + str(x[0])

# %%
titanic_df['Categoria']= titanic_df[ ['Fare','Ticket','Pclass'] ].apply(tag, axis=1)
titanic_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# 4      0            373450   8.0500   NaN        S      Allen
#
#                                         R-name                   Categoria
# 0                              Mr. Owen Harris          L-A/5 21171-3-7.25
# 1   Mrs. John Bradley (Florence Briggs Thayer)        H-PC 17599-1-71.2833
# 2                                  Miss. Laina  L-STON/O2. 3101282-3-7.925
# 3           Mrs. Jacques Heath (Lily May Peel)             H-113803-1-53.1
# 4                            Mr. William Henry             L-373450-3-8.05

# %% [markdown]
# # Parte 1

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 1 </b>:
#
#
# Encontrar el promedio de edad para los pasajeros de cada clase, así como su desviación estándar.
#
#
# </div>

# %%
titanic_df['Age'] >20
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
titanic_df[titanic_df['Pclass'] == 1]['Age'].mean()
# Out:
# 38.233440860215055

# %%
print('Para los pasajeros del la clase 3 el promedio de edad y su desviacion estandar es:', 
      titanic_df[titanic_df['Pclass'] == 3]['Age'].mean(), 'y', titanic_df[titanic_df['Pclass'] == 3]['Age'].std() )
print('Para los pasajeros del la clase 2 el promedio de edad y su desviacion estandar es:', 
      titanic_df[titanic_df['Pclass'] == 2]['Age'].mean(), 'y', titanic_df[titanic_df['Pclass'] == 2]['Age'].std() )
print('Para los pasajeros del la clase 1 el promedio de edad y su desviacion estandar es:', 
      titanic_df[titanic_df['Pclass'] == 1]['Age'].mean(), 'y', titanic_df[titanic_df['Pclass'] == 1]['Age'].std() )
# Out:
# Para los pasajeros del la clase 3 el promedio de edad y su desviacion estandar es: 25.14061971830986 y 12.495398210982415
# Para los pasajeros del la clase 2 el promedio de edad y su desviacion estandar es: 29.87763005780347 y 14.0010768124762
# Para los pasajeros del la clase 1 el promedio de edad y su desviacion estandar es: 38.233440860215055 y 14.802855896450462

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 2</b>:
#
# Encontrar el número total de pasajeros por cada punto de embarcación.
#
# </div>

# %%
print('El total de pasejeros que enbarcaron en S fueron:', (titanic_df['Embarked'] == 'S').sum()  )
print('El total de pasejeros que enbarcaron en Q fueron:', (titanic_df['Embarked'] == 'Q').sum())
print('El total de pasejeros que enbarcaron en C fueron:', (titanic_df['Embarked'] == 'C').sum())
# Out:
# El total de pasejeros que enbarcaron en S fueron: 644
# El total de pasejeros que enbarcaron en Q fueron: 77
# El total de pasejeros que enbarcaron en C fueron: 168

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 3</b>:
#
# a) Encontrar el promedio de edad de los pasajeros que sobrevivieron.
#
# b) Encontrar el promedio de edad de los hombres que sobrevivieron
#
# c) Encontrar el promedio de edad de las mujeres que sobrevivieron
# </div>

# %%
#titanic_df[titanic_df['Survived'] == 1]['Age'].mean()

# %%
print('El promedio de pasajeros sobrevivientes fue:', titanic_df[titanic_df['Survived'] == 1]['Age'].mean() )
print('El promedio de pasajeros masculinos sobrevivientes fue:', 
     titanic_df[(titanic_df['Survived'] == 1) & (titanic_df['Sex']=='male')]['Age'].mean())
print('El promedio de pasajeros femeninos sobrevivientes fue:', 
     titanic_df[(titanic_df['Survived'] == 1) & (titanic_df['Sex']=='female')]['Age'].mean())
# Out:
# El promedio de pasajeros sobrevivientes fue: 28.343689655172415
# El promedio de pasajeros masculinos sobrevivientes fue: 27.276021505376345
# El promedio de pasajeros femeninos sobrevivientes fue: 28.84771573604061

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 4</b>:
#
# ¿Cuál fue el número de sobrevivientes mujeres  mayores a 40 años? ¿Cuál era la probabilidad de supervivencia para  mujeres mayores a 40 años?
#
# </div>

# %%
#First we calculate the number of surviving females 
fem1_mean= titanic_df[ (titanic_df['Survived'] == 1) & (titanic_df['Sex']=='female') & (titanic_df['Age']>40 )]['Survived'].sum()
#print(fem1_mean)
# Out:
# 37

# %%
#We calculated the total of passengers
T_pass= titanic_df['Survived'].count()
#print(T_pass)
# Out:
# 891

# %%
pro_fem = round((fem1_mean/T_pass)*100,2) #(fem1_mean/T_pass)*100
print('El número de sobrevivientes mujeres mayores a 40 años fue',fem1_mean, 'con una probavilidad del', pro_fem, '%')
# Out:
# El número de sobrevivientes mujeres mayores a 40 años fue 37 con una probavilidad del 4.15 %

# %%
#fem1_mean= titanic_df[ (titanic_df['Survived'] == 1) & (titanic_df['Sex']=='female') & (titanic_df['Age']>40 )]['Survived'].sum()
#aaaaa= (fem1_mean/titanic_df[titanic_df['Survived']==1]['Survived'].sum())*100
#print(fem1_mean)

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 5</b>:
#
#
# Agregar una nueva columna llamada “Status”, la cual tendrá como elementos las siguientes etiquetas segun la edad:
#
# * Adult-male, si el pasajero es hombre y mayor a 21 años
# * Adult-female, si el pasajero es mujer  y mayor a 21 años
# * Minor-male, si el pasajero es hombre y su edad es menor o igual  a 21 años
# * Minor-female, si el pasajero es mujer y  su edad es menor o igual a 21 años
#
# </div>

# %%
def st_gender( x ): # Cheack this 
    if ( x[0] == 'male' ) and ( x[1] > 21 ): #The numbers indicate the variable where the function will going to act
        return 'Adult-male'
    elif ( x[0] == 'female' ) and ( x[1] > 21 ):
        return 'Adult-female'
    elif ( x[0] == 'male' ) and ( x[1] <= 21 ):
        return 'Minor-male'
    elif ( x[0] == 'female' ) and ( x[1] <= 21 ):
        return 'Minor-female'
titanic_df['Status']= titanic_df[ ['Sex','Age'] ].apply(st_gender, axis=1) #We list the variables "Sex" and "Age"
                                                                            #in the function those variales are identificated has "0" and "1"
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# 4      0            373450   8.0500   NaN        S      Allen
#
#                                         R-name                   Categoria  \
# 0                              Mr. Owen Harris          L-A/5 21171-3-7.25
# 1   Mrs. John Bradley (Florence Briggs Thayer)        H-PC 17599-1-71.2833
# 2                                  Miss. Laina  L-STON/O2. 3101282-3-7.925
# 3           Mrs. Jacques Heath (Lily May Peel)             H-113803-1-53.1
# 4                            Mr. William Henry             L-373450-3-8.05
#
#          Status
# 0    Adult-male
# 1  Adult-female
# 2  Adult-female
# 3  Adult-female
# 4    Adult-male

# %% [markdown]
# # Parte 2:  Escuelas de Jalisco
# Utilizar los datos del archivo "cct_estadistica_short.csv" para realizar los siguientes ejercicios

# %%
#Leer los datos 
schools_df = pd.read_csv('datos/cct_estadistica_short.csv',  encoding='latin1')

# %%
#Desplegar parte del dataframe
schools_df.head()
# Out:
#      CLAVE CT                    NOM TURNO                  NOMBRE CT  \
# 0  14DPR3480S                   VESPERTINO  MIGUEL HIDALGO Y COSTILLA
# 1  14DPR2780I                     MATUTINO        CONSTITUCION DEL 57
# 2  14DPR1553G  CONTINUO (JORNADA AMPLIADA)  MIGUEL HIDALGO Y COSTILLA
# 3  14SES0104Q                     MATUTINO               NIOS HEROES
# 4  14EJN0826I                   VESPERTINO        EVA GONZALEZ BLANCO
#
#                         DOMICILIO  LOCALIDAD INEGI       NOMBRE LOCALIDAD  \
# 0                    RIO SANTIAGO                1        TIZAPAN EL ALTO
# 1                        CONOCIDO               54         MESA DE MENDEZ
# 2                        CONOCIDO               31                DOLORES
# 3              ALVARO OBREGON 115              280  SANTA MARIA DEL VALLE
# 4  MARCELINO GARCIA BARRAGAN 1954                1            GUADALAJARA
#
#   NOMBRE COLONIA  MUNICIPIO NOMBRE MUNICIPIO SOSTENIMIENTO  ... DOCENTES  \
# 0     ATRACADERO         96  TIZAPAN EL ALTO  FEDERALIZADO  ...        6
# 1              0         16          AYOTLAN  FEDERALIZADO  ...        1
# 2              0         25         COLOTLAN  FEDERALIZADO  ...        3
# 3              0          8          ARANDAS    PARTICULAR  ...        9
# 4              0         39      GUADALAJARA       ESTATAL  ...        5
#
#   GRUPOS  DOCENETE EDUCACION FISICA  DOCENTE ACTIVIDADES ARTISTICAS  \
# 0      6                          1                               0
# 1      1                          0                               0
# 2      3                          1                               0
# 3      3                          1                               1
# 4      5                          1                               1
#
#    DOCENTE ACTIVIDADES TECNONOLOGICAS  DOCENTE DE IDIOMAS  \
# 0                                   0                   0
# 1                                   0                   0
# 2                                   0                   0
# 3                                   1                   0
# 4                                   0                   0
#
#    PERSONAL DE ADMINISTRATIVO Y SERVICIOS  DIRECTOR CON GRUPO  \
# 0                                       0                   0
# 1                                       0                   1
# 2                                       0                   1
# 3                                       1                   1
# 4                                       6                   0
#
#    DIRECTOR SIN GRUPO  TOTAL DE PERSONAL
# 0                   1                  8
# 1                   0                  1
# 2                   0                  4
# 3                   0                 10
# 4                   1                 14
#
# [5 rows x 43 columns]

# %%
#Resumen estadistico de los campos
schools_df.describe()
# Out:
#        LOCALIDAD INEGI    MUNICIPIO   HOMBRES 1¡   MUJERES 1¡     TOTAL 1¡  \
# count      3205.000000  3205.000000  3205.000000  3205.000000  3205.000000
# mean         68.188456    69.267395    13.990640    13.320437    27.311076
# std         352.396926    36.099546    28.627149    25.183012    52.093390
# min           1.000000     1.000000     0.000000     0.000000     0.000000
# 25%           1.000000    39.000000     0.000000     0.000000     1.000000
# 50%           3.000000    68.000000     4.000000     4.000000     7.000000
# 75%          52.000000   100.000000    15.000000    14.000000    29.000000
# max        9503.000000   125.000000   565.000000   221.000000   565.000000
#
#         HOMBRES 2¡   MUJERES 2¡     TOTAL 2¡   HOMBRES 3¡   MUJERES 3¡  ...  \
# count  3205.000000  3205.000000  3205.000000  3205.000000  3205.000000  ...
# mean     17.495476    16.978783    34.474259    16.887676    16.520437  ...
# std      24.999908    24.167297    47.835989    23.292725    22.591801  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       3.000000     2.000000     5.000000     2.000000     2.000000  ...
# 50%       9.000000     9.000000    18.000000     9.000000     9.000000  ...
# 75%      23.000000    22.000000    44.000000    23.000000    22.000000  ...
# max     427.000000   221.000000   427.000000   422.000000   201.000000  ...
#
#           DOCENTES       GRUPOS  DOCENETE EDUCACION FISICA  \
# count  3205.000000  3205.000000                3205.000000
# mean      5.691108     4.651482                   0.453978
# std       7.223604     4.293962                   0.702337
# min       0.000000     1.000000                   0.000000
# 25%       1.000000     1.000000                   0.000000
# 50%       3.000000     3.000000                   0.000000
# 75%       6.000000     6.000000                   1.000000
# max      70.000000    29.000000                   6.000000
#
#        DOCENTE ACTIVIDADES ARTISTICAS  DOCENTE ACTIVIDADES TECNONOLOGICAS  \
# count                     3205.000000                         3205.000000
# mean                         0.239938                            0.227145
# std                          0.568769                            0.900589
# min                          0.000000                            0.000000
# 25%                          0.000000                            0.000000
# 50%                          0.000000                            0.000000
# 75%                          0.000000                            0.000000
# max                          7.000000                           17.000000
#
#        DOCENTE DE IDIOMAS  PERSONAL DE ADMINISTRATIVO Y SERVICIOS  \
# count         3205.000000                             3205.000000
# mean             0.125117                                1.866459
# std              0.652190                                4.150073
# min              0.000000                                0.000000
# 25%              0.000000                                0.000000
# 50%              0.000000                                1.000000
# 75%              0.000000                                2.000000
# max             15.000000                               51.000000
#
#        DIRECTOR CON GRUPO  DIRECTOR SIN GRUPO  TOTAL DE PERSONAL
# count         3205.000000         3205.000000        3205.000000
# mean             0.409048            0.488924           8.658658
# std              0.552132            0.588820          11.393876
# min              0.000000            0.000000           0.000000
# 25%              0.000000            0.000000           1.000000
# 50%              0.000000            0.000000           5.000000
# 75%              1.000000            1.000000          11.000000
# max             10.000000            7.000000         122.000000
#
# [8 rows x 33 columns]

# %%
#Mostrar los nombres de las columnas del dataframe
schools_df.columns
# Out:
# Index(['CLAVE CT', 'NOM TURNO', 'NOMBRE CT', 'DOMICILIO', 'LOCALIDAD INEGI',
#        ' NOMBRE LOCALIDAD', 'NOMBRE COLONIA', 'MUNICIPIO', 'NOMBRE MUNICIPIO',
#        'SOSTENIMIENTO', 'NIVEL', 'PROGRAMA', 'HOMBRES 1¡', 'MUJERES 1¡',
#        'TOTAL 1¡', 'HOMBRES 2¡', 'MUJERES 2¡', 'TOTAL 2¡', 'HOMBRES 3¡',
#        'MUJERES 3¡', 'TOTAL 3¡', 'HOMBRES 4¡', 'MUJERES 4¡', 'TOTAL 4¡',
#        'HOMBRES 5¡', 'MUJERES 5¡', 'TOTAL 5¡', 'HOMBRES 6¡', 'MUJERES 6¡',
#        'TOTAL 6¡', 'HOMBRES TOTAL', 'MUJERES TOTAL', 'MATRICULA TOTAL',
#        'DOCENTES', 'GRUPOS', 'DOCENETE EDUCACION FISICA',
#        'DOCENTE ACTIVIDADES ARTISTICAS', 'DOCENTE ACTIVIDADES TECNONOLOGICAS',
#        'DOCENTE DE IDIOMAS', 'PERSONAL DE ADMINISTRATIVO Y SERVICIOS',
#        'DIRECTOR CON GRUPO', 'DIRECTOR SIN GRUPO', 'TOTAL DE PERSONAL'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-success">
#     <b>EJERCICIO 6 </b>:
#  <ul>
#   <li> Encuentre el número de estudiantes por nivel educativo (PRIMARIA, SECUNDARIA y BACHILLERATO). </li>
# </ul>
#
# </div>

# %%
schools_df['MUJERES TOTAL'][schools_df['NIVEL'] == 'SECUNDARIA'].sum()
# Out:
# 50184

# %%
print('El número de estudiantes de nivel primaria es:',schools_df['NIVEL'][schools_df['NIVEL']== 'PRIMARIA'].count())
print('El número de estudiantes de nivel primaria es:',schools_df['NIVEL'][schools_df['NIVEL']== 'SECUNDARIA'].count())
print('El número de estudiantes de nivel primaria es:',schools_df['NIVEL'][schools_df['NIVEL']== 'BACHILLERATO'].count())
# Out:
# El número de estudiantes de nivel primaria es: 1278
# El número de estudiantes de nivel primaria es: 485
# El número de estudiantes de nivel primaria es: 149

# %% [markdown]
# <div class="alert alert-success">
#     <b>EJERCICIO 7 </b>:
#  <ul>
#   <li>  Encuentre el número de estudiantes hombres y mujeres por nivel educativo (PRIMARIA, SECUNDARIA y BACHILLERATO).    </li>
# </ul>
#
# </div>

# %%
schools_df['MUJERES TOTAL'][schools_df['NIVEL'] == 'SECUNDARIA'].sum()
# Out:
# 50184

# %%
print('El número de estudiantes hombres y mujeres de nivel primaria es:',
      schools_df['HOMBRES TOTAL'][schools_df['NIVEL'] == 'PRIMARIA'].sum(), 'y', 
      schools_df['MUJERES TOTAL'][schools_df['NIVEL'] == 'PRIMARIA'].sum() )

print('El número de estudiantes hombres y mujeres de nivel secundaria es:',
      schools_df['HOMBRES TOTAL'][schools_df['NIVEL'] == 'SECUNDARIA'].sum(), 'y',
      schools_df['MUJERES TOTAL'][schools_df['NIVEL'] == 'SECUNDARIA'].sum() )

print('El número de estudiantes hombres y mujeres de nivel bachillerato es:',
      schools_df['HOMBRES TOTAL'][schools_df['NIVEL'] == 'BACHILLERATO'].sum(), 'y',
      schools_df['MUJERES TOTAL'][schools_df['NIVEL'] == 'BACHILLERATO'].sum() )
# Out:
# El número de estudiantes hombres y mujeres de nivel primaria es: 99972 y 96326
# El número de estudiantes hombres y mujeres de nivel secundaria es: 51867 y 50184
# El número de estudiantes hombres y mujeres de nivel bachillerato es: 15453 y 14315

# %% [markdown]
# <div class="alert alert-success">
#     <b>EJERCICIO 8 </b>:
#  <ul>
#   <li>  ¿Cuál es el promedio de docentes por nivel educativo?  </li>
# </ul>
#
# </div>

# %%
#Mostrar los nombres de las columnas del dataframe
schools_df.columns
# Out:
# Index(['CLAVE CT', 'NOM TURNO', 'NOMBRE CT', 'DOMICILIO', 'LOCALIDAD INEGI',
#        ' NOMBRE LOCALIDAD', 'NOMBRE COLONIA', 'MUNICIPIO', 'NOMBRE MUNICIPIO',
#        'SOSTENIMIENTO', 'NIVEL', 'PROGRAMA', 'HOMBRES 1¡', 'MUJERES 1¡',
#        'TOTAL 1¡', 'HOMBRES 2¡', 'MUJERES 2¡', 'TOTAL 2¡', 'HOMBRES 3¡',
#        'MUJERES 3¡', 'TOTAL 3¡', 'HOMBRES 4¡', 'MUJERES 4¡', 'TOTAL 4¡',
#        'HOMBRES 5¡', 'MUJERES 5¡', 'TOTAL 5¡', 'HOMBRES 6¡', 'MUJERES 6¡',
#        'TOTAL 6¡', 'HOMBRES TOTAL', 'MUJERES TOTAL', 'MATRICULA TOTAL',
#        'DOCENTES', 'GRUPOS', 'DOCENETE EDUCACION FISICA',
#        'DOCENTE ACTIVIDADES ARTISTICAS', 'DOCENTE ACTIVIDADES TECNONOLOGICAS',
#        'DOCENTE DE IDIOMAS', 'PERSONAL DE ADMINISTRATIVO Y SERVICIOS',
#        'DIRECTOR CON GRUPO', 'DIRECTOR SIN GRUPO', 'TOTAL DE PERSONAL'],
#       dtype='object')

# %%
print('El promedio de docentes en primaria es:', schools_df['DOCENTES'][schools_df['NIVEL'] == 'PRIMARIA'].mean())
print('El promedio de docentes en secundaria es:',schools_df['DOCENTES'][schools_df['NIVEL'] == 'SECUNDARIA'].mean())
print('El promedio de docentes en bachillerato es:',schools_df['DOCENTES'][schools_df['NIVEL'] == 'BACHILLERATO'].mean())
#print(ds_prim)
# Out:
# El promedio de docentes en primaria es: 5.662754303599374
# El promedio de docentes en secundaria es: 12.412371134020619
# El promedio de docentes en bachillerato es: 10.348993288590604

# %% [markdown]
# <div class="alert alert-success">
#     <b>EJERCICIO 9 </b>:
#  <ul>
#   <li>   Encuentre el porcentaje de  escuelas Particulares </li>
# </ul>
#
# </div>

# %%
p_part=round((schools_df['SOSTENIMIENTO'][schools_df['SOSTENIMIENTO'] == 'PARTICULAR'].count()/schools_df['SOSTENIMIENTO'].count())*100,2)

# %%
print('El porsentaje de descuelas particulares en el estado es:',p_part, '%')
# Out:
# El porsentaje de descuelas particulares en el estado es: 17.25 %

# %% [markdown]
# <div class="alert alert-success">
#     <b>EJERCICIO 10 </b>:
#  <ul>
#   <li>   Encuentre el porcentaje de  escuelas PREESCOLAR, PRIMARIA,  SECUNDARIA y BACHILLERATO  </li>
# </ul>
#
# </div>

# %%
schools_df['NIVEL'].count()
# Out:
# 3205

# %%
schools_df['NIVEL'][schools_df['NIVEL'] == 'PRIMARIA'].count()
# Out:
# 1278

# %%
p_pres=round((schools_df['NIVEL'][schools_df['NIVEL'] == 'PREESCOLAR'].count()/schools_df['NIVEL'].count())*100,2)
p_prim=round((schools_df['NIVEL'][schools_df['NIVEL'] == 'PRIMARIA'].count()/schools_df['NIVEL'].count())*100,2)
p_secu=round((schools_df['NIVEL'][schools_df['NIVEL'] == 'SECUNDARIA'].count()/schools_df['NIVEL'].count())*100,2)
p_bachi=round((schools_df['NIVEL'][schools_df['NIVEL'] == 'BACHILLERATO'].count()/schools_df['NIVEL'].count())*100,2)

print('El porcentaje de escuelas de niverl prescolar es:', p_pres)
print('El porcentaje de escuelas de niverl prescolar es:', p_prim)
print('El porcentaje de escuelas de niverl prescolar es:', p_secu)
print('El porcentaje de escuelas de niverl prescolar es:', p_bachi)
# Out:
# El porcentaje de escuelas de niverl prescolar es: 40.34
# El porcentaje de escuelas de niverl prescolar es: 39.88
# El porcentaje de escuelas de niverl prescolar es: 15.13
# El porcentaje de escuelas de niverl prescolar es: 4.65
